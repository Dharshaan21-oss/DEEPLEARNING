# %%
# !pip install -U langchain langchain-community langchain-text-splitters langchain-huggingface faiss-cpu
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.1/132.1 kB 3.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: langchain
#     Found existing installation: langchain 1.3.7
#     Uninstalling langchain-1.3.7:
#       Successfully uninstalled langchain-1.3.7
# ...

# %%
from langchain_community.document_loaders import TextLoader
from langchain_text_splitters import CharacterTextSplitter
from langchain_huggingface import HuggingFaceEmbeddings
from langchain_community.vectorstores import FAISS
# !pip install langchain-openai
# !pip install langchain-groq
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.5/137.5 kB 3.9 MB/s eta 0:00:00
# ...

# %%
from langchain_community.document_loaders import TextLoader
from langchain_text_splitters import CharacterTextSplitter
from langchain_community.embeddings import HuggingFaceEmbeddings
from langchain_community.vectorstores import FAISS
from langchain_classic.chains import RetrievalQA
from langchain_openai import ChatOpenAI
from langchain_groq import ChatGroq
import os

# %%
# Create dummy file if missing
if not os.path.exists('MCU.txt'):
    with open('MCU.txt', 'w') as f:
        f.write('The Marvel Cinematic Universe (MCU) is a media franchise centering on a series of superhero films.')

loader = TextLoader("MCU.txt")
documents = loader.load()
# Fixed typo: CharracterTextSplitter -> CharacterTextSplitter
splitter = CharacterTextSplitter(chunk_size=500, chunk_overlap=50)
docs = splitter.split_documents(documents)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
embeddings=HuggingFaceEmbeddings(model_name='sentence-transformers/all-MiniLM-L6-v2')
vectorstore=FAISS.from_documents(docs,embeddings)
# Out:
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]

# %%
os.environ["GROQ_API_KEY"] = "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"

# %%
llm = ChatGroq(temperature=0, groq_api_key=os.environ.get("GROQ_API_KEY"), model_name="llama-3.1-8b-instant")

# %%
qa_chain = RetrievalQA.from_chain_type(
    llm=llm,
    retriever=vectorstore.as_retriever()
)

# %%
question = "what is the diffrence between dog and puppy"
result= qa_chain.run(question)
print("Answer:",result)
# Out:
# Answer: In the context of dogs, the main difference between a dog and a puppy is the age and development stage of the animal.
#
# - A **dog** is a mature animal that has reached physical and emotional maturity. Dogs can vary in age, size, and breed, but they are generally considered adult animals.
#
# - A **puppy**, on the other hand, is a young dog that is still in the developmental stage. Puppies are typically born after a gestation period of around 58-68 days and are dependent on their mother for milk and care. As they grow, puppies go through various stages of development, including teething, socialization, and training, before becoming adult dogs.
#
# In terms of physical characteristics, puppies are generally smaller and more energetic than adult dogs. They also have a softer coat, larger eyes, and a more playful demeanor.
#
# ...
